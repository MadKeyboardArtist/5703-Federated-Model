# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
file_path = "processed_file.csv"

# %%
df_raw = pd.read_csv(file_path)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9884 entries, 0 to 9883
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   patient_id                 9884 non-null   int64
#  1   Age                        9884 non-null   int64
#  2   Sex                        9884 non-null   int64
#  3   BMI                        9884 non-null   float64
#  4   HighBP                     9884 non-null   int64
#  5   diabetes                   9884 non-null   int64
#  6   GenHlth                    9884 non-null   int64
#  7   DiffWalk                   9884 non-null   int64
#  8   HighChol                   9884 non-null   int64
#  9   HeartDiseaseorAttack       9884 non-null   int64
#  10  Age_mask                   9884 non-null   int64
#  11  Sex_mask                   9884 non-null   int64
#  12  BMI_mask                   9884 non-null   int64
# ...

# %%
# train-val-test split
# train + val vs test
tabular_train_val, tabular_test = train_test_split(
    df_raw, 
    test_size    = 0.2, 
    random_state = 42, 
    stratify = df_raw["diabetes"]
    )

# train vs val
tabular_train, tabular_val = train_test_split(
    tabular_train_val, 
    test_size    = 0.25, 
    random_state = 42, 
    stratify = tabular_train_val["diabetes"]
    )

# %%
# save to 3 CSVs
tabular_train.to_csv("tabular_wayne_train.csv", index = False)
tabular_val.to_csv  ("tabular_wayne_val.csv"  , index = False)
tabular_test.to_csv ("tabular_wayne_test.csv" , index = False)

print("Train/Val/Test saved successfully.")
# Out:
# Train/Val/Test saved successfully.
