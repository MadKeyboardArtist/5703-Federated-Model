# %% [markdown]
# final step: write site info to a .json

# %%
import json

# %%
DATASET_FOLDER = "Datasets"

# %%
# info
name      = "tabular_3"
modality  = "tabular"
label_col = "label"
n_classes = 2
train     = "diabetes_3_train.csv"
val       = "diabetes_3_val.csv"
test      = "diabetes_3_test.csv"

# %%
clean_dataset_train = f"{DATASET_FOLDER}/{name}/{train}"
clean_dataset_val   = f"{DATASET_FOLDER}/{name}/{val}"
clean_dataset_test  = f"{DATASET_FOLDER}/{name}/{test}"

info = {
    "name": name,
    "modality": modality,
    "label_col": label_col,
    "n_classes": n_classes,
    "clean_dataset_train": clean_dataset_train,
    "clean_dataset_val"  : clean_dataset_val,
    "clean_dataset_test" : clean_dataset_test,
}

with open(f"{name}_info.json", "w") as f:
    json.dump(info, f, indent=4)
