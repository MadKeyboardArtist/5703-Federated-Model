# %%
import json

# %%
tabular_tamplete = {
    # the 8 (16) features
    "age": "int",
    "age_mask": "0 or 1",
    "BMI": "float",
    "BMI_mask": "0 or 1",
}

# %%
image_tamplete = {
    "image_zise": "224 * 224",
    "channel"   : "RGB",
    "brightness": "NO opposite"
}

# %%
combined = {
    "tabular_sample_tamplete": tabular_tamplete,
    "image_sample_tamplete"  : image_tamplete
}

with open("input_sample_tamplete.json", "w") as f:
    json.dump(combined, f, indent=4)
