# %% [markdown]
# 1. Step 1 Build site_info list for all sites.

# %%
import json
import os

# %%
DATASET_FOLDER = "Datasets"

# %%
info_list = []

for item in os.scandir(DATASET_FOLDER):
    if item.is_dir():
        # is folder
        folder_name = item.name
        
        # check if last token is int
        # if folder_name.split("_")[-1].isdigit():
        if folder_name.split("_")[0] == "tabular" or folder_name.split("_")[0] == "image":
            # site folder
            print("Valid folder:", item.path)
            '''
            if folder_name == "tabular_wayne":
                continue
            '''

            # Look for JSON files inside
            for sub in os.scandir(item.path):
                if sub.is_file() and sub.name.startswith(folder_name) and sub.name.endswith("info.json"):
                    json_file = sub.path
                    # print("  Found JSON:", json_file)

                    # Load it
                    with open(json_file, "r") as f:
                        data = json.load(f)
                    info_list.append(data)
# Out:
# Valid folder: Datasets\image_1
# Valid folder: Datasets\tabular_1
# Valid folder: Datasets\tabular_3
# Valid folder: Datasets\tabular_4
# Valid folder: Datasets\tabular_rex
# Valid folder: Datasets\image_3

# %%
info_list
# Out:
# [{'name': 'image_1',
#   'modality': 'image',
#   'n_classes': 5,
#   'clean_dataset_train': 'Datasets/image_1/train',
#   'clean_dataset_val': 'Datasets/image_1/val',
#   'clean_dataset_test': 'Datasets/image_1/test'},
#  {'name': 'tabular_1',
#   'modality': 'tabular',
#   'label_col': 'Diabetes_012',
#   'n_classes': 2,
#   'clean_dataset_train': 'Datasets/tabular_1/diabetes_012_train.csv',
#   'clean_dataset_val': 'Datasets/tabular_1/diabetes_012_val.csv',
#   'clean_dataset_test': 'Datasets/tabular_1/diabetes_012_test.csv'},
#  {'name': 'tabular_3',
#   'modality': 'tabular',
#   'label_col': 'label',
#   'n_classes': 2,
#   'clean_dataset_train': 'Datasets/tabular_3/diabetes_3_train.csv',
#   'clean_dataset_val': 'Datasets/tabular_3/diabetes_3_val.csv',
#   'clean_dataset_test': 'Datasets/tabular_3/diabetes_3_test.csv'},
#  {'name': 'tabular_4',
#   'modality': 'tabular',
#   'label_col': 'Diabetes_012',
#   'n_classes': 2,
#   'clean_dataset_train': 'Datasets/tabular_4/tabular_4_train.csv',
#   'clean_dataset_val': 'Datasets/tabular_4/tabular_4_val.csv',
#   'clean_dataset_test': 'Datasets/tabular_4/tabular_4_test.csv'},
#  {'name': 'tabular_rex',
#   'modality': 'tabular',
#   'label_col': 'label',
#   'n_classes': 3,
#   'clean_dataset_train': 'Datasets/tabular_rex/tabular_rex_train.csv',
#   'clean_dataset_val': 'Datasets/tabular_rex/tabular_rex_val.csv',
#   'clean_dataset_test': 'Datasets/tabular_rex/tabular_rex_test.csv'},
#  {'name': 'image_3',
#   'modality': 'image',
#   'n_classes': 5,
#   'clean_dataset_train': 'Datasets/image_3/train',
#   'clean_dataset_val': 'Datasets/image_3/val',
#   'clean_dataset_test': 'Datasets/image_3/test'}]

# %%
with open("sites_info.json", "w") as f:
    json.dump(info_list, f, indent=4)

# %% [markdown]
# 2. Step 2 Calculate global feature stats.

# %%
DATASET_FOLDER = "Datasets"

# %%
info_list = []

for item in os.scandir(DATASET_FOLDER):
    if item.is_dir():
        # is folder
        folder_name = item.name
        
        # check if last token is int
        if folder_name.split("_")[0] == "tabular" or folder_name.split("_")[0] == "image":
            # site folder
            # print("Valid folder:", item.path)

            # Look for JSON files inside
            for sub in os.scandir(item.path):
                if sub.is_file() and sub.name.startswith(folder_name) and sub.name.endswith("stats.json"):
                    json_file = sub.path
                    # print("  Found JSON:", json_file)

                    # Load it
                    with open(json_file, "r") as f:
                        data = json.load(f)
                    info_list.append(data)

info_list
# Out:
# [{'site_name': 'tabular_1',
#   'n_samples': 229712,
#   'feature_means': {'Age': 8.085981576931113,
#    'Sex': 0.4391411854844327,
#    'BMI': 28.68571080309257,
#    'GenHlth': 2.6012049871142997,
#    'HighBP': 0.4543776554990597,
#    'DiffWalk': 0.1855584383924218,
#    'HighChol': 0.441696559169743,
#    'HeartDiseaseorAttack': 0.10321620115623041},
#   'feature_vars': {'Age': 9.5726421687767,
#    'Sex': 0.2462962046957598,
#    'BMI': 46.064766216567136,
#    'GenHlth': 1.1337465454985667,
#    'HighBP': 0.24791860168223753,
#    'DiffWalk': 0.15112650433378755,
#    'HighChol': 0.24660070878735263,
#    'HeartDiseaseorAttack': 0.09256261697510698}},
#  {'site_name': 'tabular_3',
#   'n_samples': 768,
#   'feature_means': {'Age': 33.240885416666664,
#    'Sex': 0.0,
#    'BMI': 31.992578124999998,
#    'GenHlth': 2.5494791666666665,
#    'HighBP': 0.078125,
#    'DiffWalk': 0.0,
#    'HighChol': 0.0,
#    'HeartDiseaseorAttack': 0.0},
#   'feature_vars': {'Age': 138.12296379937067,
#    'Sex': 0.0,
#    'BMI': 62.079046478271486,
#    'GenHlth': 0.9402601453993057,
#    'HighBP': 0.072021484375,
#    'DiffWalk': 0.0,
#    'HighChol': 0.0,
#    'HeartDiseaseorAttack': 0.0}},
#  {'site_name': 'tabular_4',
#   'n_samples': 100000,
#   'feature_means': {'Age': 41.885856000000004,
#    'Sex': 0.4143,
#    'BMI': 27.312758199999998,
#    'GenHlth': 0.0,
#    'HighBP': 0.07485,
#    'DiffWalk': 0.0,
#    'HighChol': 0.0,
#    'HeartDiseaseorAttack': 0.0},
#   'feature_vars': {'Age': 507.0080778039531,
#    'Sex': 0.2426579365795919,
#    'BMI': 43.769991956259936,
#    'GenHlth': 0.0,
#    'HighBP': 0.06924816998181596,
#    'DiffWalk': 0.0,
#    'HighChol': 0.0,
#    'HeartDiseaseorAttack': 0.0}},
#  {'site_name': 'tabular_rex',
#   'n_samples': 253680,
#   'feature_means': {'Age': 8.033147089112381,
#    'Sex': 0.44087241939936805,
#    'BMI': 28.38747864932335,
#    'GenHlth': 2.51104407135362,
#    'HighBP': 0.4293051240364769,
#    'DiffWalk': 0.168362793139657,
#    'HighChol': 0.4239373062198229,
#    'HeartDiseaseorAttack': 0.094501116413467},
#   'feature_vars': {'Age': 9.326239731010556,
#    'Sex': 0.24650392921231565,
#    'BMI': 43.75372312643286,
#    'GenHlth': 1.1405390987922384,
#    'HighBP': 0.24500223451250205,
#    'DiffWalk': 0.14001676302587007,
#    'HighChol': 0.24421446661490298,
#    'HeartDiseaseorAttack': 0.08557065541007537},
#   'zscore_note': 'Use z = (x - mean) / std ; std = sqrt(var) with ddof=0. Constant columns have var=0.',
#   'missing_features': [],
#   'all_nan_features': [],
#   'constant_features': []}]

# %%
len(info_list)
# Out:
# 4

# %%
from collections import defaultdict
import numpy as np

# %%
site_stats = info_list.copy()

# ---- define the global feature template ----
feature_template = [
    "Age", "Sex", "BMI", "GenHlth",
    "HighBP", "DiffWalk", "HighChol", "HeartDiseaseorAttack"
]

# %%
# ---- compute global means ----
sum_mu = defaultdict(float)
sum_n  = defaultdict(int)

for site in site_stats:
    n = int(site["n_samples"])
    for f in feature_template:
        if f in site["feature_means"]:
            sum_mu[f] += n * site["feature_means"][f]
            sum_n[f]  += n

global_mean = {
    f: (sum_mu[f] / sum_n[f]) if sum_n[f] > 0 else 0.0
    for f in feature_template
}

# ---- compute global variances ----
sum_var = defaultdict(float)

for site in site_stats:
    n = int(site["n_samples"])
    for f in feature_template:
        if f in site["feature_means"]:
            mu_i = site["feature_means"][f]
            var_i = site["feature_vars"][f]
            sum_var[f] += n * (var_i + (mu_i - global_mean[f])**2)

global_var = {
    f: (sum_var[f] / sum_n[f]) if sum_n[f] > 0 else 0.0
    for f in feature_template
}

# ---- compute std ----
global_std = {f: float(np.sqrt(v)) for f, v in global_var.items()}

# ---- final dict ----
global_stats = {
    "global_feature_mean": global_mean,
    "global_feature_std": global_std
}

# %%
global_stats
# Out:
# {'global_feature_mean': {'Age': 13.882173297668496,
#   'Sex': 0.4350631939078877,
#   'BMI': 28.32551647452812,
#   'GenHlth': 2.1166934744265036,
#   'HighBP': 0.3780250682442712,
#   'DiffWalk': 0.14608202095944292,
#   'HighChol': 0.3577913856509256,
#   'HeartDiseaseorAttack': 0.0816266831206661},
#  'global_feature_std': {'Age': 16.049739863110435,
#   'Sex': 0.4957656972915252,
#   'BMI': 6.703381964565002,
#   'GenHlth': 1.3672720127520293,
#   'HighBP': 0.4848940446802385,
#   'DiffWalk': 0.35318842578975856,
#   'HighChol': 0.4793502998902955,
#   'HeartDiseaseorAttack': 0.27379511997730066}}

# %%
# save to file
with open("global_tabular_stats.json", "w", encoding="utf-8") as f:
    json.dump(global_stats, f, indent=2, ensure_ascii=False)
