# %%
# basic preprocessing

# %%
# read all configs
import tabular_info
from multihead_model import MultiHeadModel
from config import D_TABULAR, D_EMBEDDING, D_FUSION

# %%
# build model
model = MultiHeadModel(
    d_tabular   = D_TABULAR,
    d_embedding = D_EMBEDDING,
    d_fusion    = D_FUSION,
    n_tabular_classes = tabular_info.n_tabular_classes,
    n_image_classes   = None,
    n_multi_classes   = None
)

# %%
# train the model

# %%
# evaluate the model
